# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import pprint as pprint
from scipy.stats import linregress


# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

np.random.seed(seed=42)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 583

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = f"{url}appid={weather_api_key}&units=metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{query_url}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = time.ctime(city_weather["dt"])

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | walvis bay
# Processing Record 2 of Set 1 | olonkinbyen
# Processing Record 3 of Set 1 | bethel
# Processing Record 4 of Set 1 | saint-francois
# Processing Record 5 of Set 1 | grytviken
# Processing Record 6 of Set 1 | port elizabeth
# Processing Record 7 of Set 1 | sandnessjoen
# Processing Record 8 of Set 1 | tokar
# Processing Record 9 of Set 1 | laojunmiao
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | dudinka
# Processing Record 12 of Set 1 | klyuchi
# Processing Record 13 of Set 1 | waitangi
# Processing Record 14 of Set 1 | puerto natales
# Processing Record 15 of Set 1 | tolanaro
# Processing Record 16 of Set 1 | colonia
# Processing Record 17 of Set 1 | puerto baquerizo moreno
# Processing Record 18 of Set 1 | ulladulla
# Processing Record 19 of Set 1 | ocean pointe
# City not found. Skipping...
# Processing Record 20 of Set 1 | invercargill
# Processing Record 21 of Set 1 | punta del este
# Processing Record 22 of Set 1 | afaahiti
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | thunder bay
# Processing Record 25 of Set 1 | mitu
# Processing Record 26 of Set 1 | da nang
# Processing Record 27 of Set 1 | bredasdorp
# Processing Record 28 of Set 1 | punta cana
# Processing Record 29 of Set 1 | port alfred
# Processing Record 30 of Set 1 | port-aux-francais
# Processing Record 31 of Set 1 | iqaluit
# Processing Record 32 of Set 1 | isafjordur
# Processing Record 33 of Set 1 | sitka
# Processing Record 34 of Set 1 | adamstown
# Processing Record 35 of Set 1 | yuma
# Processing Record 36 of Set 1 | luanda
# Processing Record 37 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 38 of Set 1 | thompson
# Processing Record 39 of Set 1 | queenstown
# Processing Record 40 of Set 1 | mhamid
# Processing Record 41 of Set 1 | margaret river
# Processing Record 42 of Set 1 | mbaiki
# Processing Record 43 of Set 1 | kailua-kona
# Processing Record 44 of Set 1 | bilibino
# Processing Record 45 of Set 1 | slobozhans'ke
# Processing Record 46 of Set 1 | udachny
# Processing Record 47 of Set 1 | ust-nera
# Processing Record 48 of Set 1 | ciudad de huajuapan de leon
# Processing Record 49 of Set 1 | yellowknife
# Processing Record 50 of Set 1 | blackmans bay
# Processing Record 0 of Set 2 | broken hill
# Processing Record 1 of Set 2 | ribas do rio pardo
# Processing Record 2 of Set 2 | ancud
# Processing Record 3 of Set 2 | kodinsk
# Processing Record 4 of Set 2 | coquimbo
# Processing Record 5 of Set 2 | nova sintra
# Processing Record 6 of Set 2 | kodiak
# Processing Record 7 of Set 2 | vatutine
# Processing Record 8 of Set 2 | amga
# Processing Record 9 of Set 2 | ulysses
# Processing Record 10 of Set 2 | inhambane
# Processing Record 11 of Set 2 | ribeira grande
# Processing Record 12 of Set 2 | richards bay
# Processing Record 13 of Set 2 | kerikeri
# Processing Record 14 of Set 2 | yangiobod
# Processing Record 15 of Set 2 | fuvahmulah
# City not found. Skipping...
# Processing Record 16 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 17 of Set 2 | vernon
# Processing Record 18 of Set 2 | hawaiian paradise park
# Processing Record 19 of Set 2 | shar
# Processing Record 20 of Set 2 | sake
# Processing Record 21 of Set 2 | salahonda
# Processing Record 22 of Set 2 | uturoa
# Processing Record 23 of Set 2 | road town
# Processing Record 24 of Set 2 | lebu
# Processing Record 25 of Set 2 | macapa
# Processing Record 26 of Set 2 | college
# Processing Record 27 of Set 2 | constantia
# Processing Record 28 of Set 2 | choyr
# Processing Record 29 of Set 2 | chonchi
# Processing Record 30 of Set 2 | aldinga beach
# Processing Record 31 of Set 2 | longyearbyen
# Processing Record 32 of Set 2 | happy valley-goose bay
# Processing Record 33 of Set 2 | island harbour
# Processing Record 34 of Set 2 | vorgashor
# Processing Record 35 of Set 2 | anadyr
# Processing Record 36 of Set 2 | tromso
# Processing Record 37 of Set 2 | kalmunai
# Processing Record 38 of Set 2 | westport
# Processing Record 39 of Set 2 | beaufort west
# Processing Record 40 of Set 2 | port mathurin
# Processing Record 41 of Set 2 | la ronge
# Processing Record 42 of Set 2 | mosjoen
# Processing Record 43 of Set 2 | bonthe
# Processing Record 44 of Set 2 | west island
# Processing Record 45 of Set 2 | stanley
# Processing Record 46 of Set 2 | geraldton
# Processing Record 47 of Set 2 | trairi
# Processing Record 48 of Set 2 | el granada
# Processing Record 49 of Set 2 | suva
# Processing Record 0 of Set 3 | sao tome
# Processing Record 1 of Set 3 | tranovaho
# City not found. Skipping...
# Processing Record 2 of Set 3 | lompoc
# Processing Record 3 of Set 3 | bontang
# Processing Record 4 of Set 3 | coyhaique
# Processing Record 5 of Set 3 | breves
# Processing Record 6 of Set 3 | howrah
# Processing Record 7 of Set 3 | al burayqah
# Processing Record 8 of Set 3 | montmagny
# Processing Record 9 of Set 3 | vila franca do campo
# Processing Record 10 of Set 3 | tamanrasset
# Processing Record 11 of Set 3 | saipan
# Processing Record 12 of Set 3 | konongo
# Processing Record 13 of Set 3 | papatowai
# Processing Record 14 of Set 3 | tommot
# Processing Record 15 of Set 3 | wanning
# Processing Record 16 of Set 3 | tobi village
# City not found. Skipping...
# Processing Record 17 of Set 3 | liupanshui
# City not found. Skipping...
# Processing Record 18 of Set 3 | ushuaia
# Processing Record 19 of Set 3 | haiku-pauwela
# Processing Record 20 of Set 3 | nova vicosa
# Processing Record 21 of Set 3 | sao luiz gonzaga
# Processing Record 22 of Set 3 | iskateley
# Processing Record 23 of Set 3 | naze
# Processing Record 24 of Set 3 | ola
# Processing Record 25 of Set 3 | ferkessedougou
# Processing Record 26 of Set 3 | hagere maryam
# Processing Record 27 of Set 3 | laguna
# Processing Record 28 of Set 3 | avarua
# Processing Record 29 of Set 3 | wailua homesteads
# Processing Record 30 of Set 3 | whitehorse
# Processing Record 31 of Set 3 | glogowek
# Processing Record 32 of Set 3 | rongelap
# Processing Record 33 of Set 3 | alesund
# Processing Record 34 of Set 3 | espargos
# City not found. Skipping...
# Processing Record 35 of Set 3 | ciudad acuna
# Processing Record 36 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 37 of Set 3 | kapa'a
# Processing Record 38 of Set 3 | lijiang
# Processing Record 39 of Set 3 | edinburgh of the seven seas
# Processing Record 40 of Set 3 | christchurch
# Processing Record 41 of Set 3 | zhangatas
# Processing Record 42 of Set 3 | utrik
# Processing Record 43 of Set 3 | al muwayh
# Processing Record 44 of Set 3 | labrador city
# Processing Record 45 of Set 3 | marka
# Processing Record 46 of Set 3 | goure
# Processing Record 47 of Set 3 | touros
# Processing Record 48 of Set 3 | tenno
# Processing Record 49 of Set 3 | codrington
# Processing Record 0 of Set 4 | tiksi
# Processing Record 1 of Set 4 | talnakh
# Processing Record 2 of Set 4 | 'ohonua
# City not found. Skipping...
# Processing Record 3 of Set 4 | asau
# Processing Record 4 of Set 4 | puerto ayora
# Processing Record 5 of Set 4 | phan thiet
# Processing Record 6 of Set 4 | targuist
# Processing Record 7 of Set 4 | nouadhibou
# Processing Record 8 of Set 4 | grand-bassam
# Processing Record 9 of Set 4 | cole harbour
# Processing Record 10 of Set 4 | hotan
# Processing Record 11 of Set 4 | lagos
# Processing Record 12 of Set 4 | ilhabela
# Processing Record 13 of Set 4 | bratsk
# Processing Record 14 of Set 4 | kluang
# Processing Record 15 of Set 4 | sao gabriel da cachoeira
# Processing Record 16 of Set 4 | sergeyevka
# Processing Record 17 of Set 4 | tazacorte
# Processing Record 18 of Set 4 | paris
# Processing Record 19 of Set 4 | yerofey pavlovich
# Processing Record 20 of Set 4 | hadibu
# Processing Record 21 of Set 4 | antsiranana
# Processing Record 22 of Set 4 | ginir
# Processing Record 23 of Set 4 | tchintabaraden
# Processing Record 24 of Set 4 | bryne
# Processing Record 25 of Set 4 | qarauyl
# Processing Record 26 of Set 4 | mana
# Processing Record 27 of Set 4 | cockburn town
# Processing Record 28 of Set 4 | saint-pierre
# Processing Record 29 of Set 4 | la passe
# Processing Record 30 of Set 4 | hinton
# Processing Record 31 of Set 4 | vingt cinq
# City not found. Skipping...
# Processing Record 32 of Set 4 | sterling
# Processing Record 33 of Set 4 | camana
# Processing Record 34 of Set 4 | ixtapa
# Processing Record 35 of Set 4 | fortuna
# Processing Record 36 of Set 4 | ha'il
# Processing Record 37 of Set 4 | follonica
# Processing Record 38 of Set 4 | flying fish cove
# Processing Record 39 of Set 4 | puerto aysen
# Processing Record 40 of Set 4 | kingston
# Processing Record 41 of Set 4 | berdyansk
# Processing Record 42 of Set 4 | hamilton
# Processing Record 43 of Set 4 | buka
# Processing Record 44 of Set 4 | candido mendes
# Processing Record 45 of Set 4 | georgetown
# Processing Record 46 of Set 4 | mocimboa
# Processing Record 47 of Set 4 | kone
# Processing Record 48 of Set 4 | frontera
# Processing Record 49 of Set 4 | mount isa
# Processing Record 0 of Set 5 | muzayri'
# City not found. Skipping...
# Processing Record 1 of Set 5 | valle del guamuez
# Processing Record 2 of Set 5 | mirny
# Processing Record 3 of Set 5 | galliano
# Processing Record 4 of Set 5 | golere
# Processing Record 5 of Set 5 | kattivakkam
# Processing Record 6 of Set 5 | dibba al-hisn
# Processing Record 7 of Set 5 | moundou
# Processing Record 8 of Set 5 | bargara
# City not found. Skipping...
# Processing Record 9 of Set 5 | huilong
# Processing Record 10 of Set 5 | saldanha
# Processing Record 11 of Set 5 | suoyarvi
# Processing Record 12 of Set 5 | chibougamau
# Processing Record 13 of Set 5 | plettenberg bay
# Processing Record 14 of Set 5 | tottori
# Processing Record 15 of Set 5 | al kharj
# Processing Record 16 of Set 5 | ashland
# Processing Record 17 of Set 5 | huocheng
# City not found. Skipping...
# Processing Record 18 of Set 5 | belmonte
# Processing Record 19 of Set 5 | carnarvon
# Processing Record 20 of Set 5 | moose jaw
# Processing Record 21 of Set 5 | warmbad
# Processing Record 22 of Set 5 | novodvinsk
# Processing Record 23 of Set 5 | mount pearl
# Processing Record 24 of Set 5 | arvayheer
# Processing Record 25 of Set 5 | sinabang
# Processing Record 26 of Set 5 | aasiaat
# Processing Record 27 of Set 5 | los andes
# Processing Record 28 of Set 5 | kourou
# Processing Record 29 of Set 5 | dakhla
# Processing Record 30 of Set 5 | hithadhoo
# Processing Record 31 of Set 5 | naracoorte
# Processing Record 32 of Set 5 | makinsk
# Processing Record 33 of Set 5 | gurupa
# Processing Record 34 of Set 5 | chinsali
# Processing Record 35 of Set 5 | tileagd
# Processing Record 36 of Set 5 | al jawf
# Processing Record 37 of Set 5 | hancheng
# Processing Record 38 of Set 5 | kuanda
# Processing Record 39 of Set 5 | atamaria
# City not found. Skipping...
# Processing Record 40 of Set 5 | zheleznogorsk-ilimskiy
# Processing Record 41 of Set 5 | lincoln city
# Processing Record 42 of Set 5 | ingeniero guillermo n. juarez
# Processing Record 43 of Set 5 | copala
# Processing Record 44 of Set 5 | lichinga
# Processing Record 45 of Set 5 | cabedelo
# Processing Record 46 of Set 5 | tongliao
# Processing Record 47 of Set 5 | remire-montjoly
# Processing Record 48 of Set 5 | giyani
# Processing Record 49 of Set 5 | nuuk
# Processing Record 0 of Set 6 | kristiansund
# Processing Record 1 of Set 6 | aguazul
# Processing Record 2 of Set 6 | punta arenas
# Processing Record 3 of Set 6 | maitum
# Processing Record 4 of Set 6 | tongchuanshi
# Processing Record 5 of Set 6 | taoudenni
# Processing Record 6 of Set 6 | guerrero negro
# Processing Record 7 of Set 6 | margate
# Processing Record 8 of Set 6 | saint-philippe
# Processing Record 9 of Set 6 | enewetak
# Processing Record 10 of Set 6 | mcminnville
# Processing Record 11 of Set 6 | santa cruz
# Processing Record 12 of Set 6 | griffith
# Processing Record 13 of Set 6 | dryden
# Processing Record 14 of Set 6 | waynesboro
# Processing Record 15 of Set 6 | akureyri
# Processing Record 16 of Set 6 | las navas del marques
# Processing Record 17 of Set 6 | lihue
# Processing Record 18 of Set 6 | hermanus
# Processing Record 19 of Set 6 | dourados
# Processing Record 20 of Set 6 | okha
# Processing Record 21 of Set 6 | ghanzi
# Processing Record 22 of Set 6 | keflavik
# Processing Record 23 of Set 6 | talara
# Processing Record 24 of Set 6 | motueka
# Processing Record 25 of Set 6 | pechora
# Processing Record 26 of Set 6 | meadow lake
# Processing Record 27 of Set 6 | ailuk
# Processing Record 28 of Set 6 | bile
# Processing Record 29 of Set 6 | ilulissat
# Processing Record 30 of Set 6 | fada
# Processing Record 31 of Set 6 | fort bragg
# Processing Record 32 of Set 6 | itoman
# Processing Record 33 of Set 6 | talwandi bhai
# Processing Record 34 of Set 6 | nola
# Processing Record 35 of Set 6 | klaksvik
# Processing Record 36 of Set 6 | cabo san lucas
# Processing Record 37 of Set 6 | cargados carajos
# City not found. Skipping...
# Processing Record 38 of Set 6 | karaton
# Processing Record 39 of Set 6 | bardai
# Processing Record 40 of Set 6 | kosum phisai
# Processing Record 41 of Set 6 | pimentel
# Processing Record 42 of Set 6 | charata
# Processing Record 43 of Set 6 | opladen
# Processing Record 44 of Set 6 | khandyga
# Processing Record 45 of Set 6 | bikenibeu village
# Processing Record 46 of Set 6 | fale old settlement
# Processing Record 47 of Set 6 | dubbo
# Processing Record 48 of Set 6 | murzuq
# Processing Record 49 of Set 6 | luderitz
# Processing Record 0 of Set 7 | terbanggi besar
# Processing Record 1 of Set 7 | al 'alamayn
# City not found. Skipping...
# Processing Record 2 of Set 7 | pauini
# Processing Record 3 of Set 7 | mount gambier
# Processing Record 4 of Set 7 | emerald
# Processing Record 5 of Set 7 | muisne
# Processing Record 6 of Set 7 | usinsk
# Processing Record 7 of Set 7 | plastun
# Processing Record 8 of Set 7 | tadine
# Processing Record 9 of Set 7 | beau vallon
# Processing Record 10 of Set 7 | prineville
# Processing Record 11 of Set 7 | parkway
# Processing Record 12 of Set 7 | lisala
# Processing Record 13 of Set 7 | batibo
# Processing Record 14 of Set 7 | daru
# Processing Record 15 of Set 7 | alice springs
# Processing Record 16 of Set 7 | san agustin de valle fertil
# Processing Record 17 of Set 7 | ndioum
# Processing Record 18 of Set 7 | pershore
# Processing Record 19 of Set 7 | kushtagi
# Processing Record 20 of Set 7 | xilin hot
# Processing Record 21 of Set 7 | nueva esperanza
# Processing Record 22 of Set 7 | san sebastian de la gomera
# Processing Record 23 of Set 7 | bamboo flat
# Processing Record 24 of Set 7 | saint-joseph
# Processing Record 25 of Set 7 | polyarnyy
# Processing Record 26 of Set 7 | tsiombe
# Processing Record 27 of Set 7 | bahia blanca
# Processing Record 28 of Set 7 | tobelo
# Processing Record 29 of Set 7 | toamasina
# Processing Record 30 of Set 7 | vorkuta
# Processing Record 31 of Set 7 | ulsteinvik
# Processing Record 32 of Set 7 | kolonia town
# Processing Record 33 of Set 7 | kayangel
# Processing Record 34 of Set 7 | bulgan
# Processing Record 35 of Set 7 | port douglas
# Processing Record 36 of Set 7 | arteche
# Processing Record 37 of Set 7 | urbano santos
# Processing Record 38 of Set 7 | mili
# Processing Record 39 of Set 7 | sao joao da barra
# Processing Record 40 of Set 7 | constitucion
# Processing Record 41 of Set 7 | zeya
# Processing Record 42 of Set 7 | quellon
# Processing Record 43 of Set 7 | hasaki
# Processing Record 44 of Set 7 | khovd
# Processing Record 45 of Set 7 | dadonghai
# City not found. Skipping...
# Processing Record 46 of Set 7 | atafu village
# Processing Record 47 of Set 7 | luganville
# Processing Record 48 of Set 7 | olyokminsk
# Processing Record 49 of Set 7 | brookings
# Processing Record 0 of Set 8 | tazovsky
# Processing Record 1 of Set 8 | austin
# Processing Record 2 of Set 8 | midvagur
# Processing Record 3 of Set 8 | naryshkino
# Processing Record 4 of Set 8 | katsuura
# Processing Record 5 of Set 8 | sarangani
# Processing Record 6 of Set 8 | vysokiy
# Processing Record 7 of Set 8 | fort mcmurray
# Processing Record 8 of Set 8 | callao
# Processing Record 9 of Set 8 | labuan
# Processing Record 10 of Set 8 | vylkove
# Processing Record 11 of Set 8 | port lincoln
# Processing Record 12 of Set 8 | panacan
# Processing Record 13 of Set 8 | sur
# Processing Record 14 of Set 8 | northam
# Processing Record 15 of Set 8 | baranovichi
# Processing Record 16 of Set 8 | wynyard
# Processing Record 17 of Set 8 | las khorey
# Processing Record 18 of Set 8 | bereznehuvate
# Processing Record 19 of Set 8 | nadym
# Processing Record 20 of Set 8 | qaqortoq
# Processing Record 21 of Set 8 | saint-denis
# Processing Record 22 of Set 8 | andratx
# Processing Record 23 of Set 8 | bileh savar
# City not found. Skipping...
# Processing Record 24 of Set 8 | corinth
# Processing Record 25 of Set 8 | robore
# Processing Record 26 of Set 8 | bull savanna
# Processing Record 27 of Set 8 | yulinshi
# Processing Record 28 of Set 8 | kruisfontein
# Processing Record 29 of Set 8 | dogondoutchi
# Processing Record 30 of Set 8 | jeremie
# Processing Record 31 of Set 8 | gizo
# Processing Record 32 of Set 8 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 33 of Set 8 | pangody
# Processing Record 34 of Set 8 | bodden town
# Processing Record 35 of Set 8 | arraial do cabo
# Processing Record 36 of Set 8 | patacamaya
# Processing Record 37 of Set 8 | kudat
# Processing Record 38 of Set 8 | derbent
# Processing Record 39 of Set 8 | santana
# Processing Record 40 of Set 8 | iguape
# Processing Record 41 of Set 8 | la'ie
# Processing Record 42 of Set 8 | bugiri
# Processing Record 43 of Set 8 | yuzhno-kurilsk
# Processing Record 44 of Set 8 | east london
# Processing Record 45 of Set 8 | dankalwa
# Processing Record 46 of Set 8 | itamaraca
# Processing Record 47 of Set 8 | fomeque
# Processing Record 48 of Set 8 | sinazongwe
# Processing Record 49 of Set 8 | sisimiut
# Processing Record 0 of Set 9 | sanghar
# Processing Record 1 of Set 9 | maragogi
# Processing Record 2 of Set 9 | nantucket
# Processing Record 3 of Set 9 | yibin
# Processing Record 4 of Set 9 | makurazaki
# Processing Record 5 of Set 9 | st. john's
# Processing Record 6 of Set 9 | shimoda
# Processing Record 7 of Set 9 | kralendijk
# Processing Record 8 of Set 9 | revda
# Processing Record 9 of Set 9 | wellington
# Processing Record 10 of Set 9 | veraval
# Processing Record 11 of Set 9 | tafuna
# Processing Record 12 of Set 9 | beterou
# Processing Record 13 of Set 9 | lata
# Processing Record 14 of Set 9 | cidreira
# Processing Record 15 of Set 9 | chincha alta
# Processing Record 16 of Set 9 | ujae
# Processing Record 17 of Set 9 | portland
# Processing Record 18 of Set 9 | suntar
# Processing Record 19 of Set 9 | toro
# Processing Record 20 of Set 9 | pala
# Processing Record 21 of Set 9 | north lakhimpur
# Processing Record 22 of Set 9 | george town
# Processing Record 23 of Set 9 | kabwe
# Processing Record 24 of Set 9 | freetown
# Processing Record 25 of Set 9 | rakops
# Processing Record 26 of Set 9 | kangaba
# Processing Record 27 of Set 9 | masina
# Processing Record 28 of Set 9 | seguin
# Processing Record 29 of Set 9 | nemuro
# Processing Record 30 of Set 9 | kwang binh
# Processing Record 31 of Set 9 | knyaze-volkonskoye
# Processing Record 32 of Set 9 | peniche
# Processing Record 33 of Set 9 | tarawa
# Processing Record 34 of Set 9 | khemisset
# Processing Record 35 of Set 9 | darwin
# Processing Record 36 of Set 9 | south valley
# Processing Record 37 of Set 9 | porto novo
# Processing Record 38 of Set 9 | vadso
# Processing Record 39 of Set 9 | sao jose da coroa grande
# Processing Record 40 of Set 9 | sabang
# Processing Record 41 of Set 9 | sodankyla
# Processing Record 42 of Set 9 | beolgyo
# Processing Record 43 of Set 9 | hafnarfjordur
# Processing Record 44 of Set 9 | vanimo
# Processing Record 45 of Set 9 | naqadeh
# Processing Record 46 of Set 9 | susuman
# Processing Record 47 of Set 9 | bazarak
# Processing Record 48 of Set 9 | ayabaca
# Processing Record 49 of Set 9 | zaragoza
# Processing Record 0 of Set 10 | el calafate
# Processing Record 1 of Set 10 | yinzhu
# Processing Record 2 of Set 10 | kaa-khem
# Processing Record 3 of Set 10 | furtwangen
# Processing Record 4 of Set 10 | punta de bombon
# Processing Record 5 of Set 10 | reggane
# Processing Record 6 of Set 10 | aykhal
# Processing Record 7 of Set 10 | conde
# Processing Record 8 of Set 10 | cohoes
# Processing Record 9 of Set 10 | sadjoavato
# City not found. Skipping...
# Processing Record 10 of Set 10 | isangel
# Processing Record 11 of Set 10 | al azraq ash shamali
# City not found. Skipping...
# Processing Record 12 of Set 10 | micheweni
# Processing Record 13 of Set 10 | hilo
# Processing Record 14 of Set 10 | gantang
# Processing Record 15 of Set 10 | faya-largeau
# Processing Record 16 of Set 10 | santo antonio
# Processing Record 17 of Set 10 | amos
# Processing Record 18 of Set 10 | greater sudbury
# Processing Record 19 of Set 10 | gilgit
# Processing Record 20 of Set 10 | neryungri
# Processing Record 21 of Set 10 | arroyo
# Processing Record 22 of Set 10 | tura
# Processing Record 23 of Set 10 | magadan
# Processing Record 24 of Set 10 | ebaye
# Processing Record 25 of Set 10 | zardob
# Processing Record 26 of Set 10 | padam
# City not found. Skipping...
# Processing Record 27 of Set 10 | buala
# Processing Record 28 of Set 10 | ratnagiri
# Processing Record 29 of Set 10 | kangding
# Processing Record 30 of Set 10 | bereeda
# Processing Record 31 of Set 10 | timimoun
# Processing Record 32 of Set 10 | egilsstadir
# Processing Record 33 of Set 10 | trinidad
# Processing Record 34 of Set 10 | kyaukse
# Processing Record 35 of Set 10 | horta
# Processing Record 36 of Set 10 | isle of lewis
# City not found. Skipping...
# Processing Record 37 of Set 10 | dzhalagash
# Processing Record 38 of Set 10 | juneau
# Processing Record 39 of Set 10 | villa regina
# Processing Record 40 of Set 10 | khujner
# Processing Record 41 of Set 10 | dabeiba
# Processing Record 42 of Set 10 | emure-ekiti
# Processing Record 43 of Set 10 | wad medani
# Processing Record 44 of Set 10 | zouerate
# Processing Record 45 of Set 10 | bayanhongor
# Processing Record 46 of Set 10 | frutigen
# Processing Record 47 of Set 10 | pariaman
# Processing Record 48 of Set 10 | undurkhaan
# Processing Record 49 of Set 10 | soio
# Processing Record 0 of Set 11 | hirara
# Processing Record 1 of Set 11 | lauro de freitas
# Processing Record 2 of Set 11 | abraham's bay
# City not found. Skipping...
# Processing Record 3 of Set 11 | portage la prairie
# Processing Record 4 of Set 11 | havre
# Processing Record 5 of Set 11 | zavetnoye
# Processing Record 6 of Set 11 | jinghong
# Processing Record 7 of Set 11 | as sulayyil
# Processing Record 8 of Set 11 | huayucachi
# Processing Record 9 of Set 11 | jayapura
# Processing Record 10 of Set 11 | holualoa
# Processing Record 11 of Set 11 | opuwo
# Processing Record 12 of Set 11 | kidal
# Processing Record 13 of Set 11 | khilok
# Processing Record 14 of Set 11 | mushie
# Processing Record 15 of Set 11 | yatou
# Processing Record 16 of Set 11 | mejit
# Processing Record 17 of Set 11 | nyala
# Processing Record 18 of Set 11 | oneonta
# Processing Record 19 of Set 11 | page
# Processing Record 20 of Set 11 | annaba
# Processing Record 21 of Set 11 | hami
# Processing Record 22 of Set 11 | prince george
# Processing Record 23 of Set 11 | severnoye
# Processing Record 24 of Set 11 | nar'yan-mar
# Processing Record 25 of Set 11 | fort st. john
# Processing Record 26 of Set 11 | mwene-ditu
# Processing Record 27 of Set 11 | myitkyina
# Processing Record 28 of Set 11 | mumford
# Processing Record 29 of Set 11 | usogorsk
# Processing Record 30 of Set 11 | newman
# Processing Record 31 of Set 11 | boundiali
# Processing Record 32 of Set 11 | abadan
# Processing Record 33 of Set 11 | dunedin
# Processing Record 34 of Set 11 | vilyuchinsk
# Processing Record 35 of Set 11 | dobrich
# Processing Record 36 of Set 11 | sao miguel do araguaia
# Processing Record 37 of Set 11 | pisco
# Processing Record 38 of Set 11 | puerto madero
# Processing Record 39 of Set 11 | ta`u
# Processing Record 40 of Set 11 | al kharijah
# Processing Record 41 of Set 11 | karkira
# Processing Record 42 of Set 11 | acapulco de juarez
# Processing Record 43 of Set 11 | macia
# Processing Record 44 of Set 11 | kununurra
# Processing Record 45 of Set 11 | woolgoolga
# Processing Record 46 of Set 11 | creil
# Processing Record 47 of Set 11 | ruteng
# Processing Record 48 of Set 11 | eyl
# Processing Record 49 of Set 11 | catumbela
# Processing Record 0 of Set 12 | ghadamis
# Processing Record 1 of Set 12 | enriquillo
# Processing Record 2 of Set 12 | brisas de zicatela
# Processing Record 3 of Set 12 | new norfolk
# Processing Record 4 of Set 12 | laborde
# Processing Record 5 of Set 12 | fonadhoo
# City not found. Skipping...
# Processing Record 6 of Set 12 | chhatak
# Processing Record 7 of Set 12 | laela
# Processing Record 8 of Set 12 | waddan
# Processing Record 9 of Set 12 | korkuteli
# Processing Record 10 of Set 12 | morehead city
# Processing Record 11 of Set 12 | sidi khaled
# Processing Record 12 of Set 12 | floro
# Processing Record 13 of Set 12 | samarinda
# Processing Record 14 of Set 12 | dhari
# Processing Record 15 of Set 12 | novyy urengoy
# Processing Record 16 of Set 12 | koundara
# Processing Record 17 of Set 12 | labytnangi
# Processing Record 18 of Set 12 | kushikino
# Processing Record 19 of Set 12 | zhangjiajie
# Processing Record 20 of Set 12 | senanga
# Processing Record 21 of Set 12 | netley
# Processing Record 22 of Set 12 | altamont
# Processing Record 23 of Set 12 | imbituba
# Processing Record 24 of Set 12 | russkaya polyana
# Processing Record 25 of Set 12 | sola
# Processing Record 26 of Set 12 | dhidhdhoo
# Processing Record 27 of Set 12 | vredendal
# Processing Record 28 of Set 12 | mont-dore
# Processing Record 29 of Set 12 | sougueur
# Processing Record 30 of Set 12 | nishinoomote
# Processing Record 31 of Set 12 | eirunepe
# Processing Record 32 of Set 12 | tocopilla
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          558
# Lat           558
# Lng           558
# Max Temp      558
# Humidity      558
# Cloudiness    558
# Wind Speed    558
# Country       558
# Date          558
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0      walvis bay -22.9575  14.5053     15.61        84          78
# 1     olonkinbyen  70.9221  -8.7187      1.46        85         100
# 2          bethel  41.3712 -73.4140     10.67        87         100
# 3  saint-francois  46.4154   3.9054      0.92        94         100
# 4       grytviken -54.2811 -36.5092      1.97        94          45
#
#    Wind Speed Country                      Date
# 0        1.16      NA  Sun Nov 26 20:44:47 2023
# 1        8.31      SJ  Sun Nov 26 20:44:47 2023
# 2        6.69      US  Sun Nov 26 20:41:59 2023
# 3        0.51      FR  Sun Nov 26 20:44:47 2023
# 4        4.59      GS  Sun Nov 26 20:44:48 2023

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            walvis bay -22.9575  14.5053     15.61        84          78
# 1           olonkinbyen  70.9221  -8.7187      1.46        85         100
# 2                bethel  41.3712 -73.4140     10.67        87         100
# 3        saint-francois  46.4154   3.9054      0.92        94         100
# 4             grytviken -54.2811 -36.5092      1.97        94          45
#
#          Wind Speed Country                      Date
# City_ID
# 0              1.16     NaN  Sun Nov 26 20:44:47 2023
# 1              8.31      SJ  Sun Nov 26 20:44:47 2023
# 2              6.69      US  Sun Nov 26 20:41:59 2023
# 3              0.51      FR  Sun Nov 26 20:44:47 2023
# 4              4.59      GS  Sun Nov 26 20:44:48 2023

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_axis = city_data_df["Lat"]
y_axis = city_data_df["Max Temp"]
color_values = city_data_df["Max Temp"]  # Variable used for coloring

fig1 = plt.scatter(x_axis, y_axis, marker="o", edgecolors="black", alpha=0.75, c=color_values, cmap='bwr')
plt.colorbar(fig1, label='Max Temperature (C)')

# Incorporate the other graph properties
plt.title("City Latitude vs Max Temperature (2023-011-26)")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_axis = city_data_df["Lat"]
y_axis = city_data_df["Humidity"]
fig2 = plt.scatter(x_axis, y_axis, marker="o", edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs Humidity (2023-011-26)")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_axis = city_data_df["Lat"]
y_axis = city_data_df["Cloudiness"]
fig3 = plt.scatter(x_axis, y_axis, marker="o", edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs Cloudiness (2023-011-26)")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_axis = city_data_df["Lat"]
y_axis = city_data_df["Wind Speed"]
fig4 = plt.scatter(x_axis, y_axis, marker="o", edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs Wind Speed (2023-011-26)")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
#note  code is commented out so the scatter plot doesn't auto-generate
# (slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
# regress_values = x_axis * slope + intercept
# line_eq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"
# plt.scatter(x_axis,y_axis)
# plt.plot(x_axis,regress_values,"r-")
# plt.annotate(line_eq,(-40,15), fontsize=15,color="red")
# print(f"The r value is {rvalue}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1           olonkinbyen  70.9221  -8.7187      1.46        85         100
# 2                bethel  41.3712 -73.4140     10.67        87         100
# 3        saint-francois  46.4154   3.9054      0.92        94         100
# 6          sandnessjoen  66.0217  12.6316    -20.71        71           3
# 7                 tokar  18.4254  37.7290     26.93        75          35
#
#          Wind Speed Country                      Date
# City_ID
# 1              8.31      SJ  Sun Nov 26 20:44:47 2023
# 2              6.69      US  Sun Nov 26 20:41:59 2023
# 3              0.51      FR  Sun Nov 26 20:44:47 2023
# 6              5.35      NO  Sun Nov 26 20:44:48 2023
# 7              4.12      SD  Sun Nov 26 20:44:48 2023

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            walvis bay -22.9575   14.5053     15.61        84          78
# 4             grytviken -54.2811  -36.5092      1.97        94          45
# 5        port elizabeth -33.9180   25.5701     19.62        89           0
# 12             waitangi -43.9535 -176.5597     12.24        94          93
# 13       puerto natales -51.7236  -72.4875      2.68        92          14
#
#          Wind Speed Country                      Date
# City_ID
# 0              1.16     NaN  Sun Nov 26 20:44:47 2023
# 4              4.59      GS  Sun Nov 26 20:44:48 2023
# 5              6.17      ZA  Sun Nov 26 20:44:48 2023
# 12            10.69      NZ  Sun Nov 26 20:44:49 2023
# 13             2.03      CL  Sun Nov 26 20:44:49 2023

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_axis = northern_hemi_df["Lat"]
y_axis = northern_hemi_df["Max Temp"]
plt.xlabel(x_axis.name)
plt.ylabel(y_axis.name)

print(f"The r value is {rvalue}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(10,-20), fontsize=15,color="red")
plt.show()
# Out:
# The r value is 0.6359637140158186

# %%
# Linear regression on Southern Hemisphere
x_axis = southern_hemi_df["Lat"]
y_axis = southern_hemi_df["Max Temp"]
plt.xlabel(x_axis.name)
plt.ylabel(y_axis.name)

print(f"The r value is {rvalue}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-30,2.5), fontsize=15,color="red")
plt.show()
# Out:
# The r value is 0.6359637140158186

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Both hemisphere scatter plots show that the farther from the equator, the lower the temperature

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_axis = northern_hemi_df["Lat"]
y_axis = northern_hemi_df["Humidity"]
plt.xlabel(x_axis.name)
plt.ylabel(y_axis.name)

print(f"The r value is {rvalue}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(40,20), fontsize=15,color="red")
plt.show()
# Out:
# The r value is 0.25736029896488977

# %%
# Southern Hemisphere
x_axis = southern_hemi_df["Lat"]
y_axis = southern_hemi_df["Humidity"]
plt.xlabel(x_axis.name)
plt.ylabel(y_axis.name)

print(f"The r value is {rvalue}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-25,20), fontsize=15,color="red")
plt.show()
# Out:
# The r value is 0.23290573449807575

# %% [markdown]
# **Discussion about the linear relationship:**
# There is no linear relationship between humidity and latitude.
# The r values are extreamely low

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_axis = northern_hemi_df["Lat"]
y_axis = northern_hemi_df["Cloudiness"]
plt.xlabel(x_axis.name)
plt.ylabel(y_axis.name)

print(f"The r value is {rvalue}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(40,27), fontsize=15,color="red")
plt.show()
# Out:
# The r value is 0.08488331162082986

# %%
# Southern Hemisphere
x_axis = southern_hemi_df["Lat"]
y_axis = southern_hemi_df["Cloudiness"]
plt.xlabel(x_axis.name)
plt.ylabel(y_axis.name)

print(f"The r value is {rvalue}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-55,30), fontsize=15,color="red")
plt.show()
# Out:
# The r value is 0.1426573174622541

# %% [markdown]
# **Discussion about the linear relationship:**
# There is practically no correlation between latitude and cloudiness.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_axis = northern_hemi_df["Lat"]
y_axis = northern_hemi_df["Wind Speed"]
plt.xlabel(x_axis.name)
plt.ylabel(y_axis.name)

print(f"The r value is {rvalue}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(15,14), fontsize=15,color="red")
plt.show()
# Out:
# The r value is 0.09293688400559678

# %%
# Southern Hemisphere
x_axis = southern_hemi_df["Lat"]
y_axis = southern_hemi_df["Wind Speed"]
plt.xlabel(x_axis.name)
plt.ylabel(y_axis.name)

print(f"The r value is {rvalue}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"
plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-30,12), fontsize=15,color="red")
plt.show()
# Out:
# The r value is -0.1481064914672728

# %% [markdown]
# **Discussion about the linear relationship:**
# There is basically no correlation in wind speed and latitude.
